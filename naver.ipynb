# %%
import requests

cookies = {
    'NNB': '2NWNJKPJZKOWO',
    '_fwb': '83jmvbZeoW1P82PFaiDHtf.1738549557392',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '83jmvbZeoW1P82PFaiDHtf.1738549557392',
    'nid_inf': '23232436',
    'NID_AUT': 'KkBR8BO9TRLU5qDUH7RZHhyJwZ8QtwkXYxdyO1qdROV/XS1Tnla6tv55vFJ/LfWK',
    'NID_JKL': '0/Wr/dyApEdpKByiscnVUFhT2D3otzPbb3tj2K/nuyo=',
    'NSCS': '2',
    'ASID': '0e2332a000000194df1babc90000004f',
    'NAC': 'B04bBgAHTTlfB',
    'REALESTATE': 'Thu%20Feb%2013%202025%2010%3A40%3A23%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'NACT': '1',
    'page_uid': 'iI2Zsdqo1fsss4zJSLdssssst/K-061112',
    'SRT30': '1739430247',
    'NID_SES': '...',
    'SRT5': '1739434133',
    'BUC': 'pj4SHX-9hg4jXZBY181BeNE5e8fzoerDI6foH4RAngU=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3Mzk0MTA4MjMsImV4cCI6MTczOTQyMTYyM30.35U17aoAs2BVOE6TQFpaWelEj820PIMbc3yZ12h2Te4',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/117911?ms=37.4570849,126.6442774,17&a=APT:PRE&e=RETAIL&ad=true',
    'sec-ch-ua': '"Not(A:Brand";v="99", "Google Chrome";v="133", "Chromium";v="133"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36',
    # 'cookie': 'NNB=2NWNJKPJZKOWO; _fwb=83jmvbZeoW1P82PFaiDHtf.1738549557392; landHomeFlashUseYn=Y; _fwb=83jmvbZeoW1P82PFaiDHtf.1738549557392; nid_inf=23232436; NID_AUT=KkBR8BO9TRLU5qDUH7RZHhyJwZ8QtwkXYxdyO1qdROV/XS1Tnla6tv55vFJ/LfWK; NID_JKL=0/Wr/dyApEdpKByiscnVUFhT2D3otzPbb3tj2K/nuyo=; NSCS=2; ASID=0e2332a000000194df1babc90000004f; NAC=B04bBgAHTTlfB; REALESTATE=Thu%20Feb%2013%202025%2010%3A40%3A23%20GMT%2B0900%20(Korean%20Standard%20Time); NACT=1; page_uid=iI2Zsdqo1fsss4zJSLdssssst/K-061112; SRT30=1739430247; NID_SES=...; SRT5=1739434133; BUC=pj4SHX-9hg4jXZBY181BeNE5e8fzoerDI6foH4RAngU=',
}

response = requests.get(
    'https://new.land.naver.com/api/articles/complex/117911?realEstateType=APT%3APRE&tradeType=&tag=%3A%3A%3A%3A%3A%3A%3A%3A&rentPriceMin=0&rentPriceMax=900000000&priceMin=0&priceMax=900000000&areaMin=0&areaMax=900000000&oldBuildYears&recentlyBuildYears&minHouseHoldCount&maxHouseHoldCount&showArticle=false&sameAddressGroup=true&minMaintenanceCost&maxMaintenanceCost&priceType=RETAIL&directions=&page=2&complexNo=117911&buildingNos=&areaNos=&type=list&order=rank',
    cookies=cookies,
    headers=headers,
)

response.text

# %%
import requests

cookies = {
    'NNB': '2NWNJKPJZKOWO',
    '_fwb': '83jmvbZeoW1P82PFaiDHtf.1738549557392',
    'landHomeFlashUseYn': 'Y',
    '_fwb': '83jmvbZeoW1P82PFaiDHtf.1738549557392',
    'nid_inf': '23232436',
    'NID_AUT': 'KkBR8BO9TRLU5qDUH7RZHhyJwZ8QtwkXYxdyO1qdROV/XS1Tnla6tv55vFJ/LfWK',
    'NID_JKL': '0/Wr/dyApEdpKByiscnVUFhT2D3otzPbb3tj2K/nuyo=',
    'NSCS': '2',
    'ASID': '0e2332a000000194df1babc90000004f',
    'NAC': 'B04bBgAHTTlfB',
    'REALESTATE': 'Thu%20Feb%2013%202025%2010%3A40%3A23%20GMT%2B0900%20(Korean%20Standard%20Time)',
    'NACT': '1',
    'page_uid': 'iI2Zsdqo1fsss4zJSLdssssst/K-061112',
    'SRT30': '1739430247',
    'NID_SES': '...',
    'SRT5': '1739434133',
    'BUC': 'pj4SHX-9hg4jXZBY181BeNE5e8fzoerDI6foH4RAngU=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IlJFQUxFU1RBVEUiLCJpYXQiOjE3Mzk0MTA4MjMsImV4cCI6MTczOTQyMTYyM30.35U17aoAs2BVOE6TQFpaWelEj820PIMbc3yZ12h2Te4',
    'priority': 'u=1, i',
    'referer': 'https://new.land.naver.com/complexes/117911?ms=37.4570849,126.6442774,17&a=APT:PRE&e=RETAIL&ad=true',
    'sec-ch-ua': '"Not(A:Brand";v="99", "Google Chrome";v="133", "Chromium";v="133"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36',
    # 'cookie': 'NNB=2NWNJKPJZKOWO; _fwb=83jmvbZeoW1P82PFaiDHtf.1738549557392; landHomeFlashUseYn=Y; _fwb=83jmvbZeoW1P82PFaiDHtf.1738549557392; nid_inf=23232436; NID_AUT=KkBR8BO9TRLU5qDUH7RZHhyJwZ8QtwkXYxdyO1qdROV/XS1Tnla6tv55vFJ/LfWK; NID_JKL=0/Wr/dyApEdpKByiscnVUFhT2D3otzPbb3tj2K/nuyo=; NSCS=2; ASID=0e2332a000000194df1babc90000004f; NAC=B04bBgAHTTlfB; REALESTATE=Thu%20Feb%2013%202025%2010%3A40%3A23%20GMT%2B0900%20(Korean%20Standard%20Time); NACT=1; page_uid=iI2Zsdqo1fsss4zJSLdssssst/K-061112; SRT30=1739430247; NID_SES=...; SRT5=1739434133; BUC=pj4SHX-9hg4jXZBY181BeNE5e8fzoerDI6foH4RAngU=',
}

params = {
    'index': '0',
    'representativeArticleNo': '2508149924',
}

response = requests.get('https://new.land.naver.com/api/articles', params=params, cookies=cookies, headers=headers)

response.text

# %%
import pandas as pd

# 1. 데이터프레임 생성
data = {"금액": ["5억 8,980", "6억 1,488", "6억 1,637", "6억 1,638", 
                 "6억 120", "6억 2,152", "6억 2,220", "6억 2,339", "6억 2,545"]}
df = pd.DataFrame(data)

# 2. 문자열을 숫자로 변환하는 함수
def convert_to_number(value):
    # "억"과 "만원" 단위 분리
    value = value.replace("억", "").replace(",", "")  # "5억 8,980" -> "5980"
    parts = value.split()  # 공백 기준으로 분리
    # 억 단위 처리
    if len(parts) == 2:
        first = int(parts[0]) * 10000  # 억 단위 * 10,000
        second = int(parts[1])  # 만원 단위
        return first + second  # 총 금액
    else:
        return int(parts[0]) * 10000  # 만약 "6억"만 있을 경우

# 3. 금액을 숫자로 변환하여 새로운 컬럼에 추가
df["금액(만원)"] = df["금액"].apply(convert_to_number)

# 4. 금액을 기준으로 정렬
df_sorted = df.sort_values(by="금액(만원)", ascending=True).reset_index(drop=True)

# 5. 결과 출력
print(df_sorted)
# Out:
#          금액  금액(만원)
# 0  5억 8,980   58980
# 1    6억 120   60120
# 2  6억 1,488   61488
# 3  6억 1,637   61637
# 4  6억 1,638   61638
# 5  6억 2,152   62152
# 6  6억 2,220   62220
# 7  6억 2,339   62339
# 8  6억 2,545   62545

# %%
# 1. 데이터프레임 생성
data = {
    "금액": ["7억 976", "7억 6,650"]
}
df = pd.DataFrame(data)

# 2. 문자열을 숫자로 변환하는 함수
def convert_to_number(value):
    # "억"과 "만원" 단위 분리
    value = value.replace("억", "").replace(",", "")  # "7억 976" -> "70976"
    parts = value.split()  # 공백 기준으로 분리
    # 억 단위 처리
    if len(parts) == 2:
        first = int(parts[0]) * 10000  # 억 단위 * 10,000
        second = int(parts[1])  # 만원 단위
        return first + second  # 총 금액
    else:
        return int(parts[0]) * 10000  # 만약 "7억"만 있을 경우

# 3. 금액을 숫자로 변환하여 새로운 컬럼에 추가
df["금액(만원)"] = df["금액"].apply(convert_to_number)

# 4. 금액을 기준으로 정렬
df_sorted = df.sort_values(by="금액(만원)", ascending=True).reset_index(drop=True)

# 5. 결과 출력
print(df_sorted)
# Out:
#          금액  금액(만원)
# 0    7억 976   70976
# 1  7억 6,650   76650

# %%
import requests

headers = {
    'accept': '*/*',
}

params = {
    'LAWD_CD': '28177',
    'DEAL_YMD': '202503',
    'serviceKey': 'c9kMarZn2s9YL7PZtEE/Xao+7KlEfF90wAgcvpNhzLs08xuY4Fby4+mgaYnpvUAFd5N9pJxEslrPWvYXJ0ymuA==',
    'pageNo': '1',
    'numOfRows': '10000',
}

response = requests.get(
    'http://apis.data.go.kr/1613000/RTMSDataSvcAptTradeDev/getRTMSDataSvcAptTradeDev',
    params=params,
    headers=headers,
)

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="utf-8" standalone="yes"?><response><header><resultCode>000</resultCode><resultMsg>OK</resultMsg></header><body><items><item><aptDong> </aptDong><aptNm>월드스테이트(101~111,124~132)</aptNm><aptSeq>28177-4721</aptSeq><bonbun>1614</bonbun><bubun>0000</bubun><buildYear>2008</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>36,200</dealAmount><dealDay>3</dealDay><dealMonth>3</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>인천 미추홀구</estateAgentSggNm><excluUseAr>59.996</excluUseAr
seholdGbn><rgstDate> </rgstDate><roadNm>미추홀대로733번길</roadNm><roadNmBonbun>00027</roadNmBonbun><roadNmBubun>00000</roadNmBubun><roadNmCd>4253279</roadNmCd><roadNmSeq>01</roadNmSeq><roadNmSggCd>28177</roadNmSggCd><roadNmbCd>0</roadNmbCd><sggCd>28177</sggCd><slerGbn>개인</slerGbn><umdCd>10500</umdCd><umdNm>주안동</umdNm></item><item><aptDong> </aptDong><aptNm>용현2단지금호타운</aptNm><aptSeq>28177-19</aptSeq><bonbun>0647</bonbun><bubun>0000</bubun><buildYear>1999</buildYear><buyerGbn>개인</buyerGbn><cdealDay> </cdealDay><cdealType> </cdealType><dealAmount>25,800</dealAmount><dealDay>3</dealDay><dealMonth>3</dealMonth><dealYear>2025</dealYear><dealingGbn>중개거래</dealingGbn><estateAgentSggNm>인천 미추홀구</estateAgentSggNm><excluUseAr>71.25</excluUseAr><floor>2</floor><jibun>647</jibun><landCd>1</landCd><landLeaseholdGbn>N</landLeaseholdGbn><rgstDate> </rgstDate><roadNm>매소홀로</roadNm><roadNmBonbun>00068</roadNmBonbun><roadNmBub ...

# %%
import xml.etree.ElementTree as ET

# %%
# XML 문자열을 파싱
root = ET.fromstring(response.text)

# %%
items = root.findall(".//item")

len(items)
# Out:
# 149

# %%
for item in items:
    print(item.find("aptNm").text, item.find("aptSeq").text)
# Out:
# 월드스테이트(101~111,124~132) 28177-4721
# 해든빌 28177-5648
# 용현2단지금호타운 28177-19
# 명주아르디에 28177-5504
# 용현2단지금호타운 28177-19
# 경일 28177-97
# 우성 28177-25
# 월드스테이트(101~111,124~132) 28177-4721
# 새힘아파트(오피스텔) 28177-6008
# 행복캐슬102동 28177-5695
# 진흥 28177-148
# 한신휴플러스 28177-4654
# 엑슬루타워 28177-5145
# 주안아파트 28177-128
# 월드스테이트(101~111,124~132) 28177-4721
# 진흥 28177-148
# 인천 SK Sky VIEW 28177-6035
# 서원 28177-71
# 청운 28177-86
# 인천 SK Sky VIEW 28177-6035
# 인천 SK Sky VIEW 28177-6035
# 신동아3 28177-75
# 우성 28177-25
# 풍림아이원 28177-4683
# 힐스테이트푸르지오주안 28177-6342
# 스타디움센트럴시티 28177-6721
# 용현2단지금호타운 28177-19
# 신비마을 28177-132
# 인천 SK Sky VIEW 28177-6035
# 주안파크자이더플래티넘 28177-6797
# 월드스테이트(101~111,124~132) 28177-4721
# 주안파크자이더플래티넘 28177-6797
# 신동아6 28177-78
# 신비마을 28177-132
# 우성 28177-25
# 인천 SK Sky VIEW 28177-6035
# 주안파크자이더플래티넘 28177-6797
# 신동아8 28177-80
# 힐스테이트푸르지오주안 28177-6342
# 주안지웰에스테이트 28177-6516
# 신동아7 28177-79
# 인천 SK Sky VIEW 28177-6035
# 인천 SK Sky VIEW 28177-6035
# 인천 SK Sky VIEW 28177-6035
# 동아풍림 28177-68
# 주안파크자이더플래티넘 28177-6797
# 힐스테이트푸르지오주안 28177-6342
# 동아풍림 28177-68
# 풍림아이원 28177-4683
# 우성 28177-25
# 서해 28177-15
# 광명8 28177-99
